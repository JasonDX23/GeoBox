# %%
import os, sys
sys.path.append('../../..')

from sandbox import _calibration_dir
from sandbox.sensor import Sensor, CalibSensor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_27384/864969026.py in <module>
#       2 sys.path.append('../../..')
#       3
# ----> 4 from sandbox import _calibration_dir
#       5 from sandbox.sensor import Sensor, CalibSensor
#
# ModuleNotFoundError: No module named 'sandbox'
