# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_20094/2267972701.py in <module>
#       4
#       5 import cv2
# ----> 6 cv2.imshow('Depth Camera', get_depth())
#
# error: OpenCV(4.5.5) /io/opencv/modules/highgui/src/window.cpp:1000: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
# [Stream 70] Invalid magic 7e6f
# [Stream 70] Invalid magic 57ea
# [Stream 70] Invalid magic ffff
# [Stream 70] Invalid magic ffff
# [Stream 70] Lost too many packets, resyncing...
# [Stream 70] Invalid magic fb9f
# [Stream 70] Invalid magic ffde
# [Stream 70] Invalid magic ffff
# [Stream 70] Invalid magic ffff
# [Stream 70] Invalid magic ffff
# [Stream 70] Lost too many packets, resyncing...
# iso_callback(): failed to resubmit transfer after successful completion: LIBUSB_ERROR_NO_DEVICE
# USB camera marked dead, stopping streams
# ...
